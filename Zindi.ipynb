# %%
import pandas as pd
import numpy as np

# %%
Test = pd.read_csv(r"C:\Users\SARAH\Test (2).csv")
Train = pd.read_csv(r"C:\Users\SARAH\Train (2).csv")

# %%
Train.isnull().sum()
# Out:
# user_id                0
# REGION            157520
# TENURE                 0
# MONTANT           140277
# FREQUENCE_RECH    140277
# REVENUE           134663
# ARPU_SEGMENT      134663
# FREQUENCE         134663
# DATA_VOLUME       196854
# ON_NET            145819
# ORANGE            166317
# TIGO              239386
# ZONE1             368310
# ZONE2             374487
# MRG                    0
# REGULARITY             0
# TOP_PACK          167329
# FREQ_TOP_PACK     167329
# CHURN                  0
# dtype: int64

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         400000 non-null  object
#  1   REGION          242480 non-null  object
#  2   TENURE          400000 non-null  object
#  3   MONTANT         259723 non-null  float64
#  4   FREQUENCE_RECH  259723 non-null  float64
#  5   REVENUE         265337 non-null  float64
#  6   ARPU_SEGMENT    265337 non-null  float64
#  7   FREQUENCE       265337 non-null  float64
#  8   DATA_VOLUME     203146 non-null  float64
#  9   ON_NET          254181 non-null  float64
#  10  ORANGE          233683 non-null  float64
#  11  TIGO            160614 non-null  float64
#  12  ZONE1           31690 non-null   float64
#  13  ZONE2           25513 non-null   float64
#  14  MRG             400000 non-null  object
#  15  REGULARITY      400000 non-null  int64
# ...

# %%
Train.tail()
# Out:
#                                          user_id       REGION        TENURE  \
# 399995  a892ad4ed0eda8dc721733200c47147763b183ec  TAMBACOUNDA  K > 24 month
# 399996  13daa3a651bf0192a413b339c4766aeafc6d1636          NaN  K > 24 month
# 399997  767f596aee426962f7d92f4de8d7b232cdc17568          NaN  K > 24 month
# 399998  b831e4d3b59a1e294e9e0a2aab391bc12d50845c          NaN  K > 24 month
# 399999  a80e3a164986e489102cfb538fa62e16ecc28adf          NaN  K > 24 month
#
#         MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 399995    700.0             2.0    704.0         235.0        3.0
# 399996      NaN             NaN      NaN           NaN        NaN
# 399997    700.0             2.0    699.0         233.0        5.0
# 399998      NaN             NaN      9.0           3.0        1.0
# 399999      NaN             NaN      NaN           NaN        NaN
#
#         DATA_VOLUME  ON_NET  ORANGE  TIGO  ZONE1  ZONE2 MRG  REGULARITY  \
# ...

# %%
#y= Train['CHURN']

# %%
Train["TOP_PACK"].unique()
# Out:
# array(['All-net 500F=2000F;5d', 'Data: 100 F=40MB,24H',
#        'On net 200F=Unlimited _call24H', nan, 'Data:490F=1GB,7d',
#        'Data:1000F=5GB,7d', 'VAS(IVR_Radio_Daily)',
#        'Data:200F=Unlimited,24H', 'Jokko_Daily',
#        'Mixt 250F=Unlimited_call24H', 'Data: 200 F=100MB,24H',
#        'MIXT:500F= 2500F on net _2500F off net;2d', 'Data:1000F=2GB,30d',
#        'IVR Echat_Daily_50F', 'On-net 1000F=10MilF;10d',
#        'All-net 600F= 3000F ;5d', 'Twter_U2opia_Daily',
#        'MIXT: 200mnoff net _unl on net _5Go;30d', 'On-net 500F_FNF;3d',
#        'Twter_U2opia_Weekly', 'All-net 500F =2000F_AllNet_Unlimited',
#        'Yewouleen_PKG', 'On-net 500=4000,10d', 'On-net 200F=60mn;1d',
#        'Data:3000F=10GB,30d', 'Incoming_Bonus_woma',
#        'All-net 1000=5000;5d', 'Data:500F=2GB,24H', 'Data:300F=100MB,2d',
#        'MIXT: 390F=04HOn-net_400SMS_400 Mo;4h\t', 'Data:50F=30MB_24H',
#        'All-net 1000F=(3000F On+3000F Off);5d',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
X_train_split,X_val_split, y_train_split,y_val_split=train_test_split(Train,y, test_size = 0.6)

# %%
X_train_split.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160000 entries, 47059 to 318051
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         160000 non-null  object
#  1   REGION          97060 non-null   object
#  2   TENURE          160000 non-null  object
#  3   MONTANT         103909 non-null  float64
#  4   FREQUENCE_RECH  103909 non-null  float64
#  5   REVENUE         106132 non-null  float64
#  6   ARPU_SEGMENT    106132 non-null  float64
#  7   FREQUENCE       106132 non-null  float64
#  8   DATA_VOLUME     81108 non-null   float64
#  9   ON_NET          101632 non-null  float64
#  10  ORANGE          93702 non-null   float64
#  11  TIGO            64355 non-null   float64
#  12  ZONE1           12741 non-null   float64
#  13  ZONE2           10209 non-null   float64
#  14  MRG             160000 non-null  object
#  15  REGULARITY      160000 non-null  int64
# ...

# %%
X_train_split.head(5)
# Out:
#                                          user_id       REGION        TENURE  \
# 47059   77f24ab97fefa6563eb8f886cf86ac1e5c977816   ZIGUINCHOR  K > 24 month
# 130539  efc1aa20158f1f56aceef0686045f4a4401344b0  SAINT-LOUIS  K > 24 month
# 348861  9d3a5b739673d8a5be4018cac204f27cf7a3b9c1        MATAM  K > 24 month
# 171910  a5133248b1b55f7b0f0f989caafe254d9c16b6a7          NaN  K > 24 month
# 130050  73599852f7482700abe02759793f9ce37056404e        DAKAR  K > 24 month
#
#         MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 47059       NaN             NaN      NaN           NaN        NaN
# 130539      NaN             NaN      NaN           NaN        NaN
# 348861   7100.0            17.0   7101.0        2367.0       20.0
# 171910    500.0             1.0    500.0         167.0        1.0
# 130050  21000.0            24.0  22998.0        7666.0       26.0
#
#         DATA_VOLUME  ON_NET  ORANGE  TIGO  ZONE1  ZONE2 MRG  REGULARITY  \
# ...

# %%
X_train_split["FREQ_TOP_PACK"].unique()
# Out:
# array([ nan,   7.,   1.,  17.,   2.,  12.,   9.,   5.,  42.,   8.,   3.,
#         15.,  14.,   4.,  28.,  27.,  53.,  13.,  22.,  18.,  19.,  20.,
#         21.,  33.,   6.,  32.,  31.,  29.,  41.,  26.,  16.,  11.,  36.,
#         24.,  10.,  23.,  44.,  56.,  25.,  38.,  30.,  46.,  39.,  35.,
#         34.,  61.,  40.,  79.,  55.,  50.,  59.,  51.,  47.,  86., 109.,
#         62.,  48.,  76.,  89.,  45.,  58.,  49., 100.,  37.,  54.,  43.,
#         77.,  71.,  95.,  70.,  69., 238.,  60., 101., 112.,  90.,  52.,
#         87.,  63.,  67.,  82., 629.,  78.,  88.,  68.,  57.,  74.,  75.,
#         66., 102., 257., 161., 120.,  72.,  85.,  84., 108.,  65.,  80.,
#         94.,  81., 141.,  83.,  92., 133., 170., 111.,  64., 115.,  96.,
#         91., 124.,  93., 116.,  98., 118.,  73.,  99., 129., 105., 212.,
#         97., 227., 122., 103., 114., 193., 107., 128., 113., 106., 130.,
#        163., 134., 166., 171., 104., 127., 243., 253., 119., 153., 174.,
# ...

# %%
sns.barplot(x="REVENUE",y="TENURE", data=X_train_split)

# %%
plt.figure(figsize=(15,6))
sns.heatmap(X_train_split.corr(), annot =True, cmap = 'Greens')

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="REVENUE",y="REGION", hue="CHURN", data=X_train_split)

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="REVENUE",y="MONTANT", data=X_train_split)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-e869c03d1dee> in <module>
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.barplot(x="REVENUE",y="MONTANT", data=X_train_split)
#
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
# -> 3147                           errcolor, errwidth, capsize, dodge)
#    3148
#    3149     if ax is None:
#
# ...

# %%
Train.dropna(0,subset=['REVENUE','REGION','MONTANT','ARPU_SEGMENT'], inplace= True)

# %%
Train.head()
# Out:
#                                     user_id       REGION        TENURE  \
# 0  dcf68cc2fb515ccad7d8b9b3bd80ee2a4b270063  SAINT-LOUIS  K > 24 month
# 2  ce46411b1526c94f20a383b8cb188f8d27f82a0a  TAMBACOUNDA  K > 24 month
# 3  f467cdb6669818373c26c2bad44e01ba66f97d21       FATICK  K > 24 month
# 5  2bd9ab2983615149380a63f44a66780f4fa19a4a        THIES  K > 24 month
# 8  ebfbd28870a7663d49ec79799f9fd59e8c5655ed  TAMBACOUNDA  K > 24 month
#
#    MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  \
# 0  17000.0            32.0  18000.0        6000.0       34.0          NaN
# 2   1500.0             3.0   1500.0         500.0        3.0          NaN
# 3   1500.0             3.0   2497.0         832.0        4.0          0.0
# 5   5500.0             9.0   5359.0        1786.0       19.0       6084.0
# 8  22500.0             8.0  22230.0        7410.0       16.0      14956.0
#
#    ON_NET  ORANGE   TIGO  ZONE1  ZONE2 MRG  REGULARITY  \
# ...

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201893 entries, 0 to 399995
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         201893 non-null  object
#  1   REGION          201893 non-null  object
#  2   TENURE          201893 non-null  object
#  3   MONTANT         201893 non-null  float64
#  4   FREQUENCE_RECH  201893 non-null  float64
#  5   REVENUE         201893 non-null  float64
#  6   ARPU_SEGMENT    201893 non-null  float64
#  7   FREQUENCE       201893 non-null  float64
#  8   DATA_VOLUME     135788 non-null  float64
#  9   ON_NET          185408 non-null  float64
#  10  ORANGE          183689 non-null  float64
#  11  TIGO            131183 non-null  float64
#  12  ZONE1           24531 non-null   float64
#  13  ZONE2           18995 non-null   float64
#  14  MRG             201893 non-null  object
#  15  REGULARITY      201893 non-null  int64
# ...

# %%
Train.drop(['user_id'], axis = 1, inplace = True)
Train.head()
# Out:
#         REGION        TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0  SAINT-LOUIS  K > 24 month  17000.0            32.0  18000.0        6000.0
# 2  TAMBACOUNDA  K > 24 month   1500.0             3.0   1500.0         500.0
# 3       FATICK  K > 24 month   1500.0             3.0   2497.0         832.0
# 5        THIES  K > 24 month   5500.0             9.0   5359.0        1786.0
# 8  TAMBACOUNDA  K > 24 month  22500.0             8.0  22230.0        7410.0
#
#    FREQUENCE  DATA_VOLUME  ON_NET  ORANGE   TIGO  ZONE1  ZONE2 MRG  \
# 0       34.0          NaN    97.0   355.0    6.0    NaN    NaN  NO
# 2        3.0          NaN    30.0    30.0    NaN    NaN    NaN  NO
# 3        4.0          0.0   159.0    45.0   19.0    NaN    NaN  NO
# 5       19.0       6084.0     7.0    12.0    5.0    NaN    NaN  NO
# 8       16.0      14956.0  6336.0  1017.0  185.0    NaN    NaN  NO
#
#    REGULARITY                        TOP_PACK  FREQ_TOP_PACK  CHURN
# ...

# %%
#Train["TOP_PACK"].unique()
Train.head()
# Out:
#         REGION        TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0  SAINT-LOUIS  K > 24 month  17000.0            32.0  18000.0        6000.0
# 2  TAMBACOUNDA  K > 24 month   1500.0             3.0   1500.0         500.0
# 3       FATICK  K > 24 month   1500.0             3.0   2497.0         832.0
# 5        THIES  K > 24 month   5500.0             9.0   5359.0        1786.0
# 8  TAMBACOUNDA  K > 24 month  22500.0             8.0  22230.0        7410.0
#
#    FREQUENCE  DATA_VOLUME  ON_NET  ORANGE   TIGO  ZONE1  ZONE2 MRG  \
# 0       34.0          NaN    97.0   355.0    6.0    NaN    NaN  NO
# 2        3.0          NaN    30.0    30.0    NaN    NaN    NaN  NO
# 3        4.0          0.0   159.0    45.0   19.0    NaN    NaN  NO
# 5       19.0       6084.0     7.0    12.0    5.0    NaN    NaN  NO
# 8       16.0      14956.0  6336.0  1017.0  185.0    NaN    NaN  NO
#
#    REGULARITY                        TOP_PACK  FREQ_TOP_PACK  CHURN
# ...

# %%
Train.drop(['MRG',"ZONE1","ZONE2"], axis =1, inplace=True)
Train.head()
# Out:
#         REGION        TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0  SAINT-LOUIS  K > 24 month  17000.0            32.0  18000.0        6000.0
# 2  TAMBACOUNDA  K > 24 month   1500.0             3.0   1500.0         500.0
# 3       FATICK  K > 24 month   1500.0             3.0   2497.0         832.0
# 5        THIES  K > 24 month   5500.0             9.0   5359.0        1786.0
# 8  TAMBACOUNDA  K > 24 month  22500.0             8.0  22230.0        7410.0
#
#    FREQUENCE  DATA_VOLUME  ON_NET  ORANGE   TIGO  REGULARITY  \
# 0       34.0          NaN    97.0   355.0    6.0          62
# 2        3.0          NaN    30.0    30.0    NaN          32
# 3        4.0          0.0   159.0    45.0   19.0          18
# 5       19.0       6084.0     7.0    12.0    5.0          30
# 8       16.0      14956.0  6336.0  1017.0  185.0          62
#
#                          TOP_PACK  FREQ_TOP_PACK  CHURN
# 0           All-net 500F=2000F;5d           35.0      0
# ...

# %%
Train['TOP_PACK'] = Train['TOP_PACK'].apply(lambda x: str(x).split(' ')[0])

# %%
Train["TOP_PACK"] = Train["TOP_PACK"].apply(lambda x: str(x).replace('On','On-net'))
Train["TOP_PACK"].nunique()
# Out:
# 76

# %%
Train["TENURE"].isnull().sum()
# Out:
# 0

# %%
Train["TENURE"] = Train["TENURE"].apply(lambda x: x.split('>')[0])
Train["TENURE"] = Train["TENURE"].apply(lambda x: x.split(' ')[0])
Train["TENURE"].unique()
# Out:
# array(['K', 'H', 'I', 'J', 'G', 'F', 'E', 'D'], dtype=object)

# %%
cat_features = [features for features in Train.columns if Train[features].dtype=='object']
cat_features
# Out:
# ['REGION', 'TENURE', 'TOP_PACK']

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
for i in cat_features:
    le.fit(list(Train[i].values))
    Train[i] = le.transform(list(Train[i].values))

# %%
Train.head(12)
# Out:
#     REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0        9       7  17000.0            32.0  18000.0        6000.0       34.0
# 2       11       7   1500.0             3.0   1500.0         500.0        3.0
# 3        2       7   1500.0             3.0   2497.0         832.0        4.0
# 5       12       7   5500.0             9.0   5359.0        1786.0       19.0
# 8       11       7  22500.0             8.0  22230.0        7410.0       16.0
# 11      12       7    300.0             3.0    300.0         100.0        3.0
# 12       7       7   3300.0             9.0   2996.0         999.0       10.0
# 13       0       7   4550.0            18.0   4450.0        1483.0       23.0
# 14       0       7   3800.0             7.0   3500.0        1167.0        7.0
# 15       7       7   3550.0             7.0   3550.0        1183.0        9.0
# 17       0       7  15450.0            46.0  15538.0        5179.0       51.0
# ...

# %%
#fillna
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201893 entries, 0 to 399995
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          201893 non-null  int32
#  1   TENURE          201893 non-null  int32
#  2   MONTANT         201893 non-null  float64
#  3   FREQUENCE_RECH  201893 non-null  float64
#  4   REVENUE         201893 non-null  float64
#  5   ARPU_SEGMENT    201893 non-null  float64
#  6   FREQUENCE       201893 non-null  float64
#  7   DATA_VOLUME     135788 non-null  float64
#  8   ON_NET          185408 non-null  float64
#  9   ORANGE          183689 non-null  float64
#  10  TIGO            131183 non-null  float64
#  11  REGULARITY      201893 non-null  int64
#  12  TOP_PACK        201893 non-null  int32
#  13  FREQ_TOP_PACK   185386 non-null  float64
#  14  CHURN           201893 non-null  int64
# dtypes: float64(10), int32(3), int64(2)
# memory usage: 22.3 MB

# %%
Train["ON_NET"] = Train["ON_NET"].fillna(Train["ON_NET"].mean())
Train["TIGO"] = Train["TIGO"].fillna(Train["TIGO"].mean())
Train["ORANGE"] = Train["ORANGE"].fillna(Train["ORANGE"].mean())
Train.head()
# Out:
#    REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0       9       7  17000.0            32.0  18000.0        6000.0       34.0
# 2      11       7   1500.0             3.0   1500.0         500.0        3.0
# 3       2       7   1500.0             3.0   2497.0         832.0        4.0
# 5      12       7   5500.0             9.0   5359.0        1786.0       19.0
# 8      11       7  22500.0             8.0  22230.0        7410.0       16.0
#
#    DATA_VOLUME  ON_NET  ORANGE        TIGO  REGULARITY  TOP_PACK  \
# 0          NaN    97.0   355.0    6.000000          62         7
# 2          NaN    30.0    30.0   24.846863          32         7
# 3          0.0   159.0    45.0   19.000000          18        58
# 5       6084.0     7.0    12.0    5.000000          30        24
# 8      14956.0  6336.0  1017.0  185.000000          62        16
#
#    FREQ_TOP_PACK  CHURN
# 0           35.0      0
# 2            3.0      0
# 3            3.0      0
# ...

# %%
Train["DATA_VOLUME"] = Train.groupby(["REVENUE"])['DATA_VOLUME'].apply(lambda x:x.fillna(x.mean()))
Train["FREQ_TOP_PACK"] = Train.groupby(["TOP_PACK"])['FREQ_TOP_PACK'].apply(lambda x:x.fillna(x.mean()))

# %%
Train["DATA_VOLUME"] = Train["DATA_VOLUME"].fillna(Train["DATA_VOLUME"].mean())
Train["DATA_VOLUME"].isnull().sum()
# Out:
# 0

# %%
Train["FREQ_TOP_PACK"] = Train["FREQ_TOP_PACK"].fillna(Train["FREQ_TOP_PACK"].mean())
Train["FREQ_TOP_PACK"].isnull().sum()
# Out:
# 0

# %%
Train.head()
# Out:
#    REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0       9       7  17000.0            32.0  18000.0        6000.0       34.0
# 2      11       7   1500.0             3.0   1500.0         500.0        3.0
# 3       2       7   1500.0             3.0   2497.0         832.0        4.0
# 5      12       7   5500.0             9.0   5359.0        1786.0       19.0
# 8      11       7  22500.0             8.0  22230.0        7410.0       16.0
#
#     DATA_VOLUME  ON_NET  ORANGE        TIGO  REGULARITY  TOP_PACK  \
# 0  15205.260870    97.0   355.0    6.000000          62         7
# 2    439.555864    30.0    30.0   24.846863          32         7
# 3      0.000000   159.0    45.0   19.000000          18        58
# 5   6084.000000     7.0    12.0    5.000000          30        24
# 8  14956.000000  6336.0  1017.0  185.000000          62        16
#
#    FREQ_TOP_PACK  CHURN
# 0           35.0      0
# 2            3.0      0
# 3            3.0      0
# ...

# %%
df1 = Train.loc[(Train["CHURN"] == 0)]
df1.head()
# Out:
#    REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0       9       7  17000.0            32.0  18000.0        6000.0       34.0
# 2      11       7   1500.0             3.0   1500.0         500.0        3.0
# 3       2       7   1500.0             3.0   2497.0         832.0        4.0
# 5      12       7   5500.0             9.0   5359.0        1786.0       19.0
# 8      11       7  22500.0             8.0  22230.0        7410.0       16.0
#
#     DATA_VOLUME  ON_NET  ORANGE        TIGO  REGULARITY  TOP_PACK  \
# 0  15205.260870    97.0   355.0    6.000000          62         7
# 2    439.555864    30.0    30.0   24.846863          32         7
# 3      0.000000   159.0    45.0   19.000000          18        58
# 5   6084.000000     7.0    12.0    5.000000          30        24
# 8  14956.000000  6336.0  1017.0  185.000000          62        16
#
#    FREQ_TOP_PACK  CHURN
# 0           35.0      0
# 2            3.0      0
# 3            3.0      0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200412 entries, 0 to 399995
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          200412 non-null  int32
#  1   TENURE          200412 non-null  int32
#  2   MONTANT         200412 non-null  float64
#  3   FREQUENCE_RECH  200412 non-null  float64
#  4   REVENUE         200412 non-null  float64
#  5   ARPU_SEGMENT    200412 non-null  float64
#  6   FREQUENCE       200412 non-null  float64
#  7   DATA_VOLUME     200412 non-null  float64
#  8   ON_NET          200412 non-null  float64
#  9   ORANGE          200412 non-null  float64
#  10  TIGO            200412 non-null  float64
#  11  REGULARITY      200412 non-null  int64
#  12  TOP_PACK        200412 non-null  int32
#  13  FREQ_TOP_PACK   200412 non-null  float64
#  14  CHURN           200412 non-null  int64
# dtypes: float64(10), int32(3), int64(2)
# memory usage: 22.2 MB

# %%
valid_data, unvalid_data = train_test_split(df1,  test_size = 0.01)
unvalid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2005 entries, 234089 to 165828
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          2005 non-null   int32
#  1   TENURE          2005 non-null   int32
#  2   MONTANT         2005 non-null   float64
#  3   FREQUENCE_RECH  2005 non-null   float64
#  4   REVENUE         2005 non-null   float64
#  5   ARPU_SEGMENT    2005 non-null   float64
#  6   FREQUENCE       2005 non-null   float64
#  7   DATA_VOLUME     2005 non-null   float64
#  8   ON_NET          2005 non-null   float64
#  9   ORANGE          2005 non-null   float64
#  10  TIGO            2005 non-null   float64
#  11  REGULARITY      2005 non-null   int64
#  12  TOP_PACK        2005 non-null   int32
#  13  FREQ_TOP_PACK   2005 non-null   float64
#  14  CHURN           2005 non-null   int64
# dtypes: float64(10), int32(3), int64(2)
# memory usage: 227.1 KB

# %%
df2 = Train.loc[(Train["CHURN"] == 1)]
df2.head()
# Out:
#       REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 222        0       5    500.0             1.0    822.0         274.0
# 985        5       7   6400.0            26.0   7133.0        2378.0
# 1110      11       7    500.0             1.0    769.0         256.0
# 1243       8       7   1000.0             2.0   1000.0         333.0
# 1824       0       7   1000.0             3.0    999.0         333.0
#
#       FREQUENCE  DATA_VOLUME      ON_NET  ORANGE       TIGO  REGULARITY  \
# 222         6.0   202.000000  331.722687    20.0   0.000000           6
# 985        28.0  5844.000000  198.000000    39.0  28.000000          27
# 1110        2.0     0.000000    0.000000    16.0  24.846863          12
# 1243        3.0   433.869148    2.000000    49.0  24.846863          19
# 1824        4.0   502.659847  532.000000    23.0  24.846863          11
#
#       TOP_PACK  FREQ_TOP_PACK  CHURN
# 222         73        10.0089      1
# 985         14        23.0000      1
# ...

# %%
unvalid_data.head()
# Out:
#         REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 234089       0       7   1500.0             2.0   1501.0         500.0
# 260244       0       7   1500.0             3.0   1500.0         500.0
# 325201       6       7  31500.0            58.0  32199.0       10733.0
# 388374       4       7   1600.0             7.0   3099.0        1033.0
# 182746       0       7  15200.0            23.0  15097.0        5032.0
#
#         FREQUENCE  DATA_VOLUME       ON_NET  ORANGE        TIGO  REGULARITY  \
# 234089        5.0          2.0     4.000000     5.0    2.000000          35
# 260244        3.0         10.0     7.000000    12.0    1.000000          29
# 325201       55.0        423.5  1996.000000   204.0  111.000000          62
# 388374       10.0       3058.0   331.722687    13.0   24.846863          27
# 182746       53.0        326.0    77.000000   217.0    8.000000          60
#
#         TOP_PACK  FREQ_TOP_PACK  CHURN
# 234089         7            2.0      0
# ...

# %%
frames = [df2, unvalid_data]
Data = pd.concat(frames)

# %%
Data.head()
# Out:
#       REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 222        0       5    500.0             1.0    822.0         274.0
# 985        5       7   6400.0            26.0   7133.0        2378.0
# 1110      11       7    500.0             1.0    769.0         256.0
# 1243       8       7   1000.0             2.0   1000.0         333.0
# 1824       0       7   1000.0             3.0    999.0         333.0
#
#       FREQUENCE  DATA_VOLUME      ON_NET  ORANGE       TIGO  REGULARITY  \
# 222         6.0   202.000000  331.722687    20.0   0.000000           6
# 985        28.0  5844.000000  198.000000    39.0  28.000000          27
# 1110        2.0     0.000000    0.000000    16.0  24.846863          12
# 1243        3.0   433.869148    2.000000    49.0  24.846863          19
# 1824        4.0   502.659847  532.000000    23.0  24.846863          11
#
#       TOP_PACK  FREQ_TOP_PACK  CHURN
# 222         73        10.0089      1
# 985         14        23.0000      1
# ...

# %%
Data.sample(frac=1)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3486 entries, 222 to 165828
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          3486 non-null   int32
#  1   TENURE          3486 non-null   int32
#  2   MONTANT         3486 non-null   float64
#  3   FREQUENCE_RECH  3486 non-null   float64
#  4   REVENUE         3486 non-null   float64
#  5   ARPU_SEGMENT    3486 non-null   float64
#  6   FREQUENCE       3486 non-null   float64
#  7   DATA_VOLUME     3486 non-null   float64
#  8   ON_NET          3486 non-null   float64
#  9   ORANGE          3486 non-null   float64
#  10  TIGO            3486 non-null   float64
#  11  REGULARITY      3486 non-null   int64
#  12  TOP_PACK        3486 non-null   int32
#  13  FREQ_TOP_PACK   3486 non-null   float64
#  14  CHURN           3486 non-null   int64
# dtypes: float64(10), int32(3), int64(2)
# memory usage: 394.9 KB

# %%
X = Data.drop(["CHURN"], axis = 1)
Y = Data["CHURN"]

# %%
X.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1BEFB510>,
# ...
#       dtype=object)

# %%
#building the models
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train,y_val =train_test_split(X,Y, test_size=0.25)

# %%
X_train.shape
# Out:
# (2614, 14)

# %%
y_train.shape
# Out:
# (2614,)

# %%
X_val.shape
# Out:
# (872, 14)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components= None, svd_solver = 'full')
X_train = pca.fit_transform(X_train)
X_val = pca.transform(X_val)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [4.56846791e-01 9.46136317e-02 7.65995752e-02 7.19846882e-02
#  6.92980751e-02 5.61412049e-02 4.72221102e-02 4.40345777e-02
#  4.11048784e-02 2.51464497e-02 1.21658815e-02 2.91104951e-03
#  1.93108637e-03 4.11292560e-10]

# %%
clf = RandomForestClassifier(n_estimators= 100 , min_samples_split = 3, 
                            )

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(min_samples_split=3)

# %%
y_pred = clf.predict(X_val)
print(clf.score(X_train,y_train))
print(clf.score(X_val,y_val))
# Out:
# 0.9980872226472839
# 0.8222477064220184

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_val,y_pred)
cm
# Out:
# array([[432,  76],
#        [ 78, 286]], dtype=int64)

# %%
y_pred = clf.predict(X_val)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_val,y_pred)

# %%
cm
# Out:
# array([[432,  76],
#        [ 78, 286]], dtype=int64)

# %%
clf.feature_importances_
# Out:
# array([0.16666667, 0.03333333, 0.2       , 0.        , 0.06666667,
#        0.        , 0.06666667, 0.13333333, 0.16666667, 0.1       ,
#        0.        , 0.03333333, 0.03333333, 0.        ])

# %%
def plot_feature_importances_expresso(model):
    n_features = X.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align ='center')
    plt.yticks(np.arange(n_features), X.columns)

# %%
plot_feature_importances_expresso(clf)

# %%
print(results)
# Out:
# 0.9929996037511557

# %%
print(results_train)
# Out:
# 0.992549088979303

# %%
Test.head()
# Out:
#                                     user_id REGION        TENURE  MONTANT  \
# 0  af900d87e73b7ff6509d2203df4704a98aa5f2a6    NaN  K > 24 month      NaN
# 1  5335efd940280b82143272275637d1e65d37eadb    NaN  K > 24 month      NaN
# 2  a581f4fa08677c26f83f643248c667e241043086    NaN  K > 24 month   1900.0
# 3  64f67177d0775262b8087a9e2e3b8061b6324ae6  DAKAR  K > 24 month   3000.0
# 4  0d6009a4594c4be22449b8d9cc01a0bcea98faea  DAKAR  K > 24 month  32000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0             NaN      NaN           NaN        NaN          NaN     NaN
# 1             NaN     10.0           3.0        1.0          NaN     NaN
# 2            15.0   2299.0         766.0       21.0        414.0     NaN
# 3             9.0   2603.0         868.0       14.0        332.0     0.0
# 4            47.0  33000.0       11000.0       47.0          NaN   128.0
#
#    ORANGE   TIGO  ZONE1  ZONE2 MRG  REGULARITY               TOP_PACK  \
# ...

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         100000 non-null  object
#  1   REGION          60707 non-null   object
#  2   TENURE          100000 non-null  object
#  3   MONTANT         65049 non-null   float64
#  4   FREQUENCE_RECH  65049 non-null   float64
#  5   REVENUE         66510 non-null   float64
#  6   ARPU_SEGMENT    66510 non-null   float64
#  7   FREQUENCE       66510 non-null   float64
#  8   DATA_VOLUME     50662 non-null   float64
#  9   ON_NET          63617 non-null   float64
#  10  ORANGE          58800 non-null   float64
#  11  TIGO            40212 non-null   float64
#  12  ZONE1           7680 non-null    float64
#  13  ZONE2           6422 non-null    float64
#  14  MRG             100000 non-null  object
#  15  REGULARITY      100000 non-null  int64
# ...

# %%
submission2 = pd.DataFrame()
submission2["user_id"] = Test["user_id"]

# %%
Test.drop(['user_id'], axis = 1, inplace = True)
Test.head()
# Out:
#   REGION        TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0    NaN  K > 24 month      NaN             NaN      NaN           NaN
# 1    NaN  K > 24 month      NaN             NaN     10.0           3.0
# 2    NaN  K > 24 month   1900.0            15.0   2299.0         766.0
# 3  DAKAR  K > 24 month   3000.0             9.0   2603.0         868.0
# 4  DAKAR  K > 24 month  32000.0            47.0  33000.0       11000.0
#
#    FREQUENCE  DATA_VOLUME  ON_NET  ORANGE   TIGO  ZONE1  ZONE2 MRG  \
# 0        NaN          NaN     NaN     NaN    NaN    NaN    NaN  NO
# 1        1.0          NaN     NaN     NaN    NaN    NaN    NaN  NO
# 2       21.0        414.0     NaN     7.0    2.0    NaN    NaN  NO
# 3       14.0        332.0     0.0    23.0    4.0    NaN    NaN  NO
# 4       47.0          NaN   128.0   555.0  280.0    NaN    NaN  NO
#
#    REGULARITY               TOP_PACK  FREQ_TOP_PACK
# 0           1                    NaN            NaN
# ...

# %%
Test.drop(['MRG',"ZONE1","ZONE2"], axis =1, inplace=True)
Test.head()
# Out:
#   REGION        TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0    NaN  K > 24 month      NaN             NaN      NaN           NaN
# 1    NaN  K > 24 month      NaN             NaN     10.0           3.0
# 2    NaN  K > 24 month   1900.0            15.0   2299.0         766.0
# 3  DAKAR  K > 24 month   3000.0             9.0   2603.0         868.0
# 4  DAKAR  K > 24 month  32000.0            47.0  33000.0       11000.0
#
#    FREQUENCE  DATA_VOLUME  ON_NET  ORANGE   TIGO  REGULARITY  \
# 0        NaN          NaN     NaN     NaN    NaN           1
# 1        1.0          NaN     NaN     NaN    NaN           2
# 2       21.0        414.0     NaN     7.0    2.0          27
# 3       14.0        332.0     0.0    23.0    4.0          46
# 4       47.0          NaN   128.0   555.0  280.0          61
#
#                 TOP_PACK  FREQ_TOP_PACK
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2   Data: 100 F=40MB,24H           17.0
# ...

# %%
Test['TOP_PACK'] = Test['TOP_PACK'].apply(lambda x: str(x).split(' ')[0])

# %%
Test["TOP_PACK"] = Test["TOP_PACK"].apply(lambda x: str(x).replace('On','On-net'))
Test["TOP_PACK"].nunique()
# Out:
# 66

# %%
Test["TENURE"] = Test["TENURE"].apply(lambda x: x.split('>')[0])
Test["TENURE"] = Test["TENURE"].apply(lambda x: x.split(' ')[0])
Test["TENURE"].unique()
# Out:
# array(['K', 'I', 'H', 'F', 'E', 'G', 'J', 'D'], dtype=object)

# %%
cat2_features = [features for features in Test.columns if Test[features].dtype=='object']
cat2_features
# Out:
# ['REGION', 'TENURE', 'TOP_PACK']

# %%
from sklearn.preprocessing import LabelEncoder
le2= LabelEncoder()
for i in cat2_features:
    le2.fit(list(Test[i].values))
    Test[i] = le2.transform(list(Test[i].values))

# %%
Test["ON_NET"] = Test["ON_NET"].fillna(Test["ON_NET"].mean())
Test["TIGO"] = Test["TIGO"].fillna(Test["TIGO"].mean())
Test["ORANGE"] = Test["ORANGE"].fillna(Test["ORANGE"].mean())
Test.head()
# Out:
#    REGION  TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0      14       7      NaN             NaN      NaN           NaN        NaN
# 1      14       7      NaN             NaN     10.0           3.0        1.0
# 2      14       7   1900.0            15.0   2299.0         766.0       21.0
# 3       0       7   3000.0             9.0   2603.0         868.0       14.0
# 4       0       7  32000.0            47.0  33000.0       11000.0       47.0
#
#    DATA_VOLUME      ON_NET      ORANGE        TIGO  REGULARITY  TOP_PACK  \
# 0          NaN  279.370703   94.900799   23.459291           1        65
# 1          NaN  279.370703   94.900799   23.459291           2        65
# 2        414.0  279.370703    7.000000    2.000000          27         7
# 3        332.0    0.000000   23.000000    4.000000          46        32
# 4          NaN  128.000000  555.000000  280.000000          61         4
#
#    FREQ_TOP_PACK
# 0            NaN
# 1            NaN
# ...

# %%
Test["DATA_VOLUME"] = Test.groupby(["REVENUE"])['DATA_VOLUME'].apply(lambda x:x.fillna(x.mean()))
Test["FREQ_TOP_PACK"] = Test.groupby(["TOP_PACK"])['FREQ_TOP_PACK'].apply(lambda x:x.fillna(x.mean()))

# %%
Test["DATA_VOLUME"] = Test["DATA_VOLUME"].fillna(Test["DATA_VOLUME"].mean())
Test["DATA_VOLUME"].isnull().sum()
# Out:
# 0

# %%
Test["FREQ_TOP_PACK"] = Test["FREQ_TOP_PACK"].fillna(Test["FREQ_TOP_PACK"].mean())
Test["FREQ_TOP_PACK"].isnull().sum()
# Out:
# 0

# %%
Test["MONTANT"] = Test["MONTANT"].fillna(Test["MONTANT"].mean())
Test["FREQUENCE"] = Test["FREQUENCE"].fillna(Test["FREQUENCE"].mean())
Test["FREQUENCE_RECH"] = Test["FREQUENCE_RECH"].fillna(Test["FREQUENCE_RECH"].mean())
Test["ARPU_SEGMENT"] = Test["ARPU_SEGMENT"].fillna(Test["ARPU_SEGMENT"].mean())
Test["REVENUE"] = Test["REVENUE"].fillna(Test["REVENUE"].mean())

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          100000 non-null  int32
#  1   TENURE          100000 non-null  int32
#  2   MONTANT         100000 non-null  float64
#  3   FREQUENCE_RECH  100000 non-null  float64
#  4   REVENUE         100000 non-null  float64
#  5   ARPU_SEGMENT    100000 non-null  float64
#  6   FREQUENCE       100000 non-null  float64
#  7   DATA_VOLUME     100000 non-null  float64
#  8   ON_NET          100000 non-null  float64
#  9   ORANGE          100000 non-null  float64
#  10  TIGO            100000 non-null  float64
#  11  REGULARITY      100000 non-null  int64
#  12  TOP_PACK        100000 non-null  int32
#  13  FREQ_TOP_PACK   100000 non-null  float64
# dtypes: float64(10), int32(3), int64(1)
# memory usage: 9.5 MB

# %%
clf = RandomForestClassifier(n_estimators= 100 , min_samples_split = 3, 
                            )
clf.fit(X,Y)
# Out:
# RandomForestClassifier(min_samples_split=3)

# %%
pred = clf.predict_proba(Test)

# %%
pred
# Out:
# array([[0.26      , 0.74      ],
#        [0.27583333, 0.72416667],
#        [0.6125    , 0.3875    ],
#        ...,
#        [0.7475    , 0.2525    ],
#        [0.49333333, 0.50666667],
#        [0.275     , 0.725     ]])

# %%
pred2 = pd.DataFrame(pred)
pred2
# Out:
#               0         1
# 0      0.260000  0.740000
# 1      0.275833  0.724167
# 2      0.612500  0.387500
# 3      0.926667  0.073333
# 4      0.971667  0.028333
# ...         ...       ...
# 99995  0.775833  0.224167
# 99996  0.689167  0.310833
# 99997  0.747500  0.252500
# 99998  0.493333  0.506667
# 99999  0.275000  0.725000
#
# [100000 rows x 2 columns]

# %%
submission2.shape
# Out:
# (100000, 1)

# %%
submission2["Churn"] = pred[:,1]

# %%
submission2.head()
# Out:
#                                     user_id     Churn
# 0  af900d87e73b7ff6509d2203df4704a98aa5f2a6  0.740000
# 1  5335efd940280b82143272275637d1e65d37eadb  0.724167
# 2  a581f4fa08677c26f83f643248c667e241043086  0.387500
# 3  64f67177d0775262b8087a9e2e3b8061b6324ae6  0.073333
# 4  0d6009a4594c4be22449b8d9cc01a0bcea98faea  0.028333

# %%
 submission2.to_csv("Zindi_submission.csv", index = False)
